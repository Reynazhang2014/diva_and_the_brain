# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json
import time

# %%
sample1 = pd.read_csv('250_sample_1.csv')
sample2 = pd.read_csv('250_sample_2.csv')
sample3 = pd.read_csv('250_sample_3.csv')
sample4 = pd.read_csv('250_sample_4.csv')
sample5 = pd.read_csv('250_sample_5.csv')
sample5.head()
# Out:
#    zip_code  total  non_hispanic_tot  \
# 0     21075   7299              7173
# 1     39341   2880              2859
# 2     55092   3163              3150
# 3     32960   9312              8927
# 4     71129   5057              4963
#
#    Not Hispanic or Latino householder: - Householder who is White alone  \
# 0                                               5974
# 1                                                963
# 2                                               3111
# 3                                               8339
# 4                                               3140
#
#    Not Hispanic or Latino householder: - Householder who is Black or African American alone  \
# 0                                                718
# 1                                               1876
# 2                                                  7
# 3                                                395
# 4                                               1729
#
#    Not Hispanic or Latino householder: - Householder who is American Indian and Alaska Native alone  \
# 0                                                 26
# 1                                                  7
# 2                                                 10
# 3                                                 17
# 4                                                 26
#
#    Not Hispanic or Latino householder: - Householder who is Asian alone  \
# 0                                                353
# 1                                                  2
# 2                                                  7
# 3                                                 85
# 4                                                 26
#
#    Not Hispanic or Latino householder: - Householder who is Native Hawaiian and Other Pacific Islander alone  \
# 0                                                  2
# 1                                                  0
# 2                                                  0
# 3                                                  2
# 4                                                  1
#
#    Not Hispanic or Latino householder: - Householder who is Some other race alone  \
# 0                                                  7
# 1                                                  2
# 2                                                  0
# 3                                                  4
# 4                                                  3
#
#    Not Hispanic or Latino householder: - Householder who is Two or more races  \
# 0                                                 93
# 1                                                  9
# 2                                                 15
# 3                                                 85
# 4                                                 38
#
#      ...              Id_zip  per_capita_income_2017_estimate  \
# 0    ...      8600000US21075                          41396.0
# 1    ...      8600000US39341                          14771.0
# 2    ...      8600000US55092                          34118.0
# 3    ...      8600000US32960                          26184.0
# 4    ...      8600000US71129                          24079.0
#
#    per_capita_income_2017_margin  white_tot  black_tot  indian_tot  asian_tot  \
# 0                         1900.0       7299       6041         722         26
# 1                         1914.0       2880        970        1885          7
# 2                         2206.0       3163       3119           7         11
# 3                         3657.0       9312       8605         407         17
# 4                         3216.0       5057       3198        1733         27
#
#    native_tot other_tot  mixed_tot
# 0         356         2         45
# 1           2         0          7
# 2           7         0          3
# 3          86         2         96
# 4          27         1         24
#
# [5 rows x 28 columns]

# %%
allsamples = [sample1, sample2, sample3, sample4, sample5]

# %%
#add back the trailing 0's
for sample_data in allsamples:
    sample_data['zip_code'] = sample_data['zip_code'].astype('str')
    fun = lambda x : '0'+ str(x) if len(x) == 4 else ('00'+ str(x) if len(x) == 3 else str(x))
    sample_data['zip_code'] = sample_data['zip_code'].apply(fun)

# %%
#Set up Columns to populate from each query

for sample_data in allsamples:
    sample_data['chinese_count'] = 0
    sample_data['ch_tot_review_ct'] = 0
    sample_data['ch_avg_review_ct'] = 0
    sample_data['ch_avg_rating'] = 0
    sample_data['mexican_count'] = 0
    sample_data['mx_tot_review_ct'] = 0
    sample_data['mx_avg_review_ct'] = 0
    sample_data['mx_avg_rating'] = 0    
    sample_data['fastfood_count'] = 0
    sample_data['ff_tot_review_ct'] = 0
    sample_data['ff_avg_review_ct'] = 0
    sample_data['ff_avg_rating'] = 0

# %%
#Define parameters for API call
from config import api_key
base_url = 'https://api.yelp.com/v3/businesses/search?'
head = {'Authorization': 'Bearer '+ api_key}
params = {
    'categories': '',
    'limit': 50, #max limit is 50
    'radius': 3000
       }

# %%
params['categories'] = 'mexican'
#Use this line if you just want to do for one of the samples. comment out if you want to use the loop
#sample_data = sample1
t0 = time.time()

for sample_data in allsamples:
    i = 1
    for index,row in sample_data.iterrows():
        while i <= 250:
            i +=1
            params['location'] = row['zip_code']
            output = requests.get(base_url, params, headers=head).json()
            tot_review_count = 0
            tot_rating = 0
            tot_count = 0
            for restaurant in output['businesses']:
                tot_count = output['total']
                tot_review_count += restaurant['review_count']
                tot_rating += restaurant['rating']
            if tot_count <= params['limit']:
                    pass
            else:
                num = params['limit']
                while num < tot_count:
                    params['offest'] = num
                    output = requests.get(base_url, params, headers=head).json()
                    for restaurant in output['businesses']:
                        tot_review_count += restaurant['review_count']
                        tot_rating += restaurant['rating']
                    num += params['limit']
            try:
                sample_data.loc[index,'mexican_count'] = output['total']
                sample_data.loc[index,'mx_tot_review_ct'] = tot_review_count
                sample_data.loc[index,'mx_avg_review_ct'] = round(tot_review_count/tot_count,2)
                sample_data.loc[index,'mx_avg_rating'] = round(tot_rating/tot_count,2)
            except ZeroDivisionError:
                print(f'iteration {i} division by zero')
            break

print(f'run time = {time.time() - t0}')
# Out:
# iteration 4 division by zero
# iteration 6 division by zero
# iteration 9 division by zero
# iteration 10 division by zero
# iteration 11 division by zero
# iteration 14 division by zero
# iteration 15 division by zero
# iteration 17 division by zero
# iteration 24 division by zero
# iteration 37 division by zero
# iteration 39 division by zero
# iteration 41 division by zero
# iteration 43 division by zero
# iteration 47 division by zero
# iteration 63 division by zero
# iteration 65 division by zero
# iteration 68 division by zero
# iteration 72 division by zero
# iteration 74 division by zero
# iteration 75 division by zero
# iteration 76 division by zero
# iteration 79 division by zero
# iteration 80 division by zero
# iteration 86 division by zero
# iteration 92 division by zero
# iteration 95 division by zero
# iteration 103 division by zero
# iteration 114 division by zero
# iteration 119 division by zero
# iteration 120 division by zero
# iteration 121 division by zero
# iteration 123 division by zero
# iteration 124 division by zero
# iteration 126 division by zero
# iteration 127 division by zero
# iteration 128 division by zero
# iteration 129 division by zero
# iteration 133 division by zero
# iteration 135 division by zero
# iteration 136 division by zero
# iteration 138 division by zero
# iteration 139 division by zero
# iteration 142 division by zero
# iteration 147 division by zero
# iteration 150 division by zero
# iteration 154 division by zero
# iteration 156 division by zero
# iteration 161 division by zero
# iteration 167 division by zero
# iteration 173 division by zero
# iteration 175 division by zero
# iteration 177 division by zero
# iteration 180 division by zero
# iteration 184 division by zero
# iteration 187 division by zero
# iteration 191 division by zero
# iteration 207 division by zero
# iteration 218 division by zero
# iteration 221 division by zero
# iteration 226 division by zero
# iteration 232 division by zero
# iteration 233 division by zero
# iteration 234 division by zero
# iteration 235 division by zero
# iteration 249 division by zero
# iteration 251 division by zero
# iteration 4 division by zero
# iteration 8 division by zero
# iteration 15 division by zero
# iteration 17 division by zero
# iteration 18 division by zero
# iteration 21 division by zero
# iteration 23 division by zero
# iteration 25 division by zero
# iteration 31 division by zero
# iteration 33 division by zero
# iteration 34 division by zero
# iteration 35 division by zero
# iteration 38 division by zero
# iteration 39 division by zero
# iteration 43 division by zero
# iteration 45 division by zero
# iteration 53 division by zero
# iteration 55 division by zero
# iteration 56 division by zero
# iteration 59 division by zero
# iteration 183 division by zero
# iteration 190 division by zero
# iteration 192 division by zero
# iteration 194 division by zero
# iteration 201 division by zero
# iteration 205 division by zero
# iteration 210 division by zero
# iteration 211 division by zero
# iteration 213 division by zero
# iteration 222 division by zero
# iteration 224 division by zero
# iteration 227 division by zero
# iteration 229 division by zero
# iteration 232 division by zero
# iteration 233 division by zero
# iteration 236 division by zero
# iteration 237 division by zero
# iteration 239 division by zero
# iteration 240 division by zero
# iteration 243 division by zero
# iteration 244 division by zero
# iteration 247 division by zero
# run time = 708.248966217041

# %%
params['categories'] = 'chinese'
#Use this line if you just want to do for one of the samples. comment out if you want to use the loop
#sample_data = sample1


for sample_data in allsamples:
    i = 1
    for index,row in sample_data.iterrows():
        while i <= 250:
            i +=1
            params['location'] = row['zip_code']
            output = requests.get(base_url, params, headers=head).json()
            tot_review_count = 0
            tot_rating = 0
            tot_count = 0
            for restaurant in output['businesses']:
                tot_count = output['total']
                tot_review_count += restaurant['review_count']
                tot_rating += restaurant['rating']
            if tot_count <= params['limit']:
                    pass
            else:
                num = params['limit']
                while num < tot_count:
                    params['offest'] = num
                    output = requests.get(base_url, params, headers=head).json()
                    for restaurant in output['businesses']:
                        tot_review_count += restaurant['review_count']
                        tot_rating += restaurant['rating']
                    num += params['limit']
            try:
                sample_data.loc[index,'chinese_count'] = output['total']
                sample_data.loc[index,'ch_tot_review_ct'] = tot_review_count
                sample_data.loc[index,'ch_avg_review_ct'] = round(tot_review_count/tot_count,2)
                sample_data.loc[index,'ch_avg_rating'] = round(tot_rating/tot_count,2)
            except ZeroDivisionError:
                print('division by zero')
            break
# Out:
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero
# division by zero

# %%
params['categories'] = 'hotdogs'
#Use this line if you just want to do for one of the samples. comment out if you want to use the loop
#sample_data = sample1

t0 = time.time()

for sample_data in allsamples:
    i = 1
    for index,row in sample_data.iterrows():
        while i <= 250:
            i +=1
            params['location'] = row['zip_code']
            output = requests.get(base_url, params, headers=head).json()
            tot_review_count = 0
            tot_rating = 0
            tot_count = 0
            for restaurant in output['businesses']:
                tot_count = output['total']
                tot_review_count += restaurant['review_count']
                tot_rating += restaurant['rating']
            if tot_count <= params['limit']:
                    pass
            else:
                num = params['limit']
                while num < tot_count:
                    params['offest'] = num
                    output = requests.get(base_url, params, headers=head).json()
                    for restaurant in output['businesses']:
                        tot_review_count += restaurant['review_count']
                        tot_rating += restaurant['rating']
                    num += params['limit']
            try:
                sample_data.loc[index,'fastfood_count'] = output['total']
                sample_data.loc[index,'ff_tot_review_ct'] = tot_review_count
                sample_data.loc[index,'ff_avg_review_ct'] = round(tot_review_count/tot_count,2)
                sample_data.loc[index,'ff_avg_rating'] = round(tot_rating/tot_count,2)
            except ZeroDivisionError:
                pass
            break
    print(f'time elapsed = {time.time() - t0}')
            

print(f'Total run time = {time.time() - t0}')
# Out:
# time elapsed = 140.72525906562805
# time elapsed = 283.5190510749817
# time elapsed = 421.7944321632385
# time elapsed = 558.2060701847076
# time elapsed = 692.1128251552582
# Total run time = 692.1129972934723

# %%
sample4.head(10)
# Out:
#   zip_code  total  non_hispanic_tot  \
# 0    58078   5813              5754
# 1    78602   6279              5572
# 2    29180   5521              5470
# 3    70062   6604              6171
# 4    62208   5939              5856
# 5    11238  21104             19154
# 6    60645  16136             14350
# 7    29902   9098              8847
# 8    78758  18024             13844
# 9    44136  16209             16075
#
#    Not Hispanic or Latino householder: - Householder who is White alone  \
# 0                                               5650
# 1                                               4805
# 2                                               2509
# 3                                               3307
# 4                                               4824
# 5                                               3813
# 6                                              10066
# 7                                               6733
# 8                                              10136
# 9                                              15329
#
#    Not Hispanic or Latino householder: - Householder who is Black or African American alone  \
# 0                                                 16
# 1                                                633
# 2                                               2929
# 3                                               2706
# 4                                                896
# 5                                              13814
# 6                                               1638
# 7                                               1935
# 8                                               1992
# 9                                                207
#
#    Not Hispanic or Latino householder: - Householder who is American Indian and Alaska Native alone  \
# 0                                                 45
# 1                                                 36
# 2                                                  2
# 3                                                 28
# 4                                                  9
# 5                                                 47
# 6                                                 27
# 7                                                 21
# 8                                                 38
# 9                                                  6
#
#    Not Hispanic or Latino householder: - Householder who is Asian alone  \
# 0                                                 10
# 1                                                 36
# 2                                                  9
# 3                                                 57
# 4                                                 71
# 5                                                714
# 6                                               1974
# 7                                                 70
# 8                                               1338
# 9                                                429
#
#    Not Hispanic or Latino householder: - Householder who is Native Hawaiian and Other Pacific Islander alone  \
# 0                                                  2
# 1                                                  1
# 2                                                  0
# 3                                                  1
# 4                                                  0
# 5                                                 17
# 6                                                  8
# 7                                                 10
# 8                                                  8
# 9                                                  1
#
#    Not Hispanic or Latino householder: - Householder who is Some other race alone  \
# 0                                                  3
# 1                                                  3
# 2                                                  2
# 3                                                  6
# 4                                                  2
# 5                                                112
# 6                                                 77
# 7                                                  3
# 8                                                 33
# 9                                                  1
#
#    Not Hispanic or Latino householder: - Householder who is Two or more races  \
# 0                                                 28
# 1                                                 58
# 2                                                 19
# 3                                                 66
# 4                                                 54
# 5                                                637
# 6                                                560
# 7                                                 75
# 8                                                299
# 9                                                102
#
#        ...        ch_avg_review_ct  ch_avg_rating  mexican_count  \
# 0      ...                    0.00           0.00              0
# 1      ...                   54.00           2.50             14
# 2      ...                    4.00           3.50              1
# 3      ...                   34.75           3.12             15
# 4      ...                   28.20           3.40              5
# 5      ...                  109.86           4.38             96
# 6      ...                   87.07           3.10             44
# 7      ...                    0.00           0.00              1
# 8      ...                  271.71           3.61             63
# 9      ...                   32.67           3.00              7
#
#    mx_tot_review_ct  mx_avg_review_ct  mx_avg_rating  fastfood_count  \
# 0                 0              0.00           0.00               0
# 1               365             26.07           3.21              12
# 2                 2              2.00           2.50               1
# 3               678             45.20           3.03              25
# 4               209             41.80           3.60              17
# 5             24798            258.31           4.06              74
# 6              2869             65.20           3.69              40
# 7                36             36.00           4.00               0
# 8             13992            222.10           6.13              29
# 9               179             25.57           3.14              15
#
#    ff_tot_review_ct ff_avg_review_ct  ff_avg_rating
# 0                 0             0.00           0.00
# 1               195            16.25           2.46
# 2                 1             1.00           1.00
# 3               345            13.80           2.26
# 4               300            17.65           3.00
# 5              3152            42.59           3.93
# 6              1234            30.85           2.75
# 7                 0             0.00           0.00
# 8              1236            42.62           2.79
# 9               234            15.60           3.07
#
# [10 rows x 40 columns]

# %%
plt.scatter(sample1['per_capita_income_2017_estimate'],sample1['fastfood_count'])

# %%
sample1.to_csv('250_sample_1_Results.csv', index=False)
sample2.to_csv('250_sample_2_Results.csv', index=False)
sample3.to_csv('250_sample_3_Results.csv', index=False)
sample4.to_csv('250_sample_4_Results.csv', index=False)
sample5.to_csv('250_sample_5_Results.csv', index=False)
