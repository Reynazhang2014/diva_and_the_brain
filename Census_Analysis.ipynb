# %%
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import requests 
import numpy as np

# %%
census = pd.read_csv('./DEC_00_SF1_H007.csv')
census.rename(columns={'Id2':'zip_code','Total:':'total',
                       'Not Hispanic or Latino householder:':'non_hispanic_tot',
                      'Hispanic or Latino householder:':'hispanic_tot'},inplace = True)
income = pd.read_csv('Income_Data.csv')
income.rename(columns={'Estimate; Per capita income in the past 12 months (in 2017 inflation-adjusted dollars)': 
                       'per_capita_income_2017_estimate',
                      'Margin of Error; Per capita income in the past 12 months (in 2017 inflation-adjusted dollars)':
                      'per_capita_income_2017_margin'},inplace = True)

# %%
#need to use inner join as there are some 991HH, 991XX zip codes in the census data with no income analysis
zip_income = pd.merge(census,income, on = 'Id',how = 'inner',suffixes =['_income','_zip'])
#delete the puerto rican zip codes
# add back the trailing 0's for zip codes less than 5 digits
zip_income['zip_code'] = zip_income['zip_code'].astype('str')
fun = lambda x : '0'+ str(x) if len(x) == 4 else ('00'+ str(x) if len(x) == 3 else str(x))
zip_income['zip_code'] = zip_income['zip_code'].apply(fun)

# %%
#Calculate the total people for each race, regardless of hispanic or not
list_race = ['white_tot','black_tot','indian_tot','asian_tot','native_tot','other_tot','mixed_tot']
i = 1
for race in list_race:
    zip_income[race] = zip_income.iloc[:,3+i] + zip_income.iloc[:,11+i]
    i+= 1
    
zip_income.head()
# Out:
#                Id zip_code Geography_income  total  non_hispanic_tot  \
# 0  8600000US00601    00601      ZCTA5 00601   5895                27
# 1  8600000US00602    00602      ZCTA5 00602  13520                98
# 2  8600000US00603    00603      ZCTA5 00603  19152               229
# 3  8600000US00606    00606      ZCTA5 00606   2013                13
# 4  8600000US00610    00610      ZCTA5 00610   9262                73
#
#    Not Hispanic or Latino householder: - Householder who is White alone  \
# 0                                                 23
# 1                                                 79
# 2                                                185
# 3                                                 11
# 4                                                 61
#
#    Not Hispanic or Latino householder: - Householder who is Black or African American alone  \
# 0                                                  2
# 1                                                  6
# 2                                                 19
# 3                                                  1
# 4                                                  6
#
#    Not Hispanic or Latino householder: - Householder who is American Indian and Alaska Native alone  \
# 0                                                  0
# 1                                                  0
# 2                                                  1
# 3                                                  0
# 4                                                  0
#
#    Not Hispanic or Latino householder: - Householder who is Asian alone  \
# 0                                                  1
# 1                                                  3
# 2                                                 16
# 3                                                  1
# 4                                                  5
#
#    Not Hispanic or Latino householder: - Householder who is Native Hawaiian and Other Pacific Islander alone  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#      ...      Geography_zip  per_capita_income_2017_estimate  \
# 0    ...        ZCTA5 00601                           7041.0
# 1    ...        ZCTA5 00602                           8978.0
# 2    ...        ZCTA5 00603                          10897.0
# 3    ...        ZCTA5 00606                           5960.0
# 4    ...        ZCTA5 00610                           9266.0
#
#    per_capita_income_2017_margin  white_tot  black_tot  indian_tot  asian_tot  \
# 0                          775.0       5895       5618          67          8
# 1                          597.0      13520      11908         558         22
# 2                          819.0      19152      15789        1028         37
# 3                          708.0       2013       1812          77          4
# 4                          542.0       9262       7824         447         23
#
#    native_tot  other_tot  mixed_tot
# 0           1          0        104
# 1           8          1        631
# 2          33          4       1718
# 3           1          0         50
# 4          10          0        524
#
# [5 rows x 31 columns]

# %%
# subset the data and make sure that the zip code contains 5000 or more people
census_sub = zip_income.loc[(zip_income['total'] >= 5000)&(~zip_income['zip_code'].str.startswith('00')),:]

# %%
# randomly select 100 zip code out of subset census data
census_sub_sample = census_sub.sample(n = 100,random_state=100).reset_index(drop = True)

# %%
census_sub_sample_short = census_sub_sample.drop(columns=['Geography_income','Id2'])
census_sub_sample_short.head()
# Out:
#                Id zip_code  total  non_hispanic_tot  \
# 0  8600000US01850    01850   5680              5056
# 1  8600000US99502    99502   6576              6358
# 2  8600000US33126    33126  15244               946
# 3  8600000US10035    10035  11169              5865
# 4  8600000US10029    10029  27465             12873
#
#    Not Hispanic or Latino householder: - Householder who is White alone  \
# 0                                               4484
# 1                                               5192
# 2                                                699
# 3                                                483
# 4                                               2688
#
#    Not Hispanic or Latino householder: - Householder who is Black or African American alone  \
# 0                                                204
# 1                                                226
# 2                                                 94
# 3                                               5033
# 4                                               8557
#
#    Not Hispanic or Latino householder: - Householder who is American Indian and Alaska Native alone  \
# 0                                                  5
# 1                                                301
# 2                                                  8
# 3                                                 23
# 4                                                 63
#
#    Not Hispanic or Latino householder: - Householder who is Asian alone  \
# 0                                                248
# 1                                                403
# 2                                                101
# 3                                                 88
# 4                                                945
#
#    Not Hispanic or Latino householder: - Householder who is Native Hawaiian and Other Pacific Islander alone  \
# 0                                                  0
# 1                                                 24
# 2                                                  4
# 3                                                  1
# 4                                                  2
#
#    Not Hispanic or Latino householder: - Householder who is Some other race alone  \
# 0                                                 10
# 1                                                  6
# 2                                                  5
# 3                                                 26
# 4                                                 98
#
#      ...     Geography_zip  per_capita_income_2017_estimate  \
# 0    ...       ZCTA5 01850                          19486.0
# 1    ...       ZCTA5 99502                          41256.0
# 2    ...       ZCTA5 33126                          17570.0
# 3    ...       ZCTA5 10035                          21618.0
# 4    ...       ZCTA5 10029                          27966.0
#
#    per_capita_income_2017_margin  white_tot  black_tot  indian_tot  asian_tot  \
# 0                         1964.0       5680       4737         221          8
# 1                         2823.0       6576       5292         231        313
# 2                          970.0      15244      13432         322         23
# 3                         1727.0      11169       2426        5594         83
# 4                         1641.0      27465       8159        9960        225
#
#    native_tot  other_tot mixed_tot
# 0         249          0       312
# 1         407         26        81
# 2         105          6       810
# 3          93          8      2402
# 4         977         18      6592
#
# [5 rows x 29 columns]

# %%
census_sub_sample_short.to_csv('sample_census2_100.csv')
